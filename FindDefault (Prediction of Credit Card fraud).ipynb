# %%
#importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Loading the data set
df = pd.read_csv("/content/drive/MyDrive/creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
#first 5 rows
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Last 5 rows
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# checking for the number of missing values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Distribution of non Fraudulent transactions & Fraudulent Transactions
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#Seperating the data for Analysis
fraud = df[df.Class == 1]
non_fraud = df[df.Class == 0]

# %%
non_fraud.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
# Statistical Measures of the data
non_fraud.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# Statistical Measures of the data
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#Compare the values for both transactions
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Build a sample Dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions ----> 492

# %%
non_fraud_sample = non_fraud.sample(n=492)

# %%
non_fraud_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279684  169029.0  2.048629 -0.367489 -2.544065 -0.728472  2.387380  3.318407
# 193518  130169.0  2.080152 -0.992287 -0.801193 -0.316387 -1.095972 -0.861556
# 208751  137256.0 -0.616217 -0.390294  0.657761 -2.354112  0.667513 -1.105439
# 219060  141578.0  1.637149 -1.215307 -0.788944  0.574019 -0.089768  1.620323
# 172061  120937.0  1.828424  0.357172  0.350213  3.725494 -0.231331  0.365355
# ...          ...       ...       ...       ...       ...       ...       ...
# 68502    53021.0 -2.923918 -0.676851  2.100624 -0.623648 -0.072930  0.253719
# 52944    45728.0  1.259985 -0.895159  1.083790 -0.533468 -1.467359  0.153999
# 133330   80340.0  0.964621  0.287542  0.264538  1.342398  0.464446  1.116241
# 179023  123891.0  1.997632  0.275553 -1.945197  1.035115  0.890416 -0.680557
# 94737    65009.0  1.213938 -0.022487 -0.181354  0.979252  0.395140  0.869548
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279684 -0.477692  0.791276  0.403246  ... -0.292703 -0.835377  0.380780
# 193518 -0.688245 -0.149169  0.058034  ... -0.369796 -0.583782  0.267047
# 208751  0.145951 -0.049400 -1.437412  ...  0.492708  1.093832 -0.292204
# 219060 -0.719414  0.408515 -0.191236  ... -0.575824 -1.284330  0.471007
# 172061 -0.470625  0.214984 -0.735357  ... -0.143005 -0.422536  0.440547
# ...          ...       ...       ...  ...       ...       ...       ...
# 68502   0.036923  0.119889  0.963704  ... -0.347120 -0.051933  0.456325
# 52944  -1.155808  0.178354 -0.322912  ... -0.431945 -0.654457  0.066926
# 133330 -0.210537  0.421727  0.231540  ... -0.164136 -0.092444  0.157574
# 179023  0.680713 -0.281484 -0.445482  ...  0.185336  0.552426  0.004926
# 94737  -0.192556  0.326881  0.417271  ... -0.160982 -0.352168 -0.220859
#
#              V24       V25       V26       V27       V28  Amount  Class
# 279684  0.698235 -0.265199  0.219159 -0.052337 -0.066750    1.98      0
# 193518 -0.149192 -0.417916  0.566911 -0.047929 -0.049811   45.00      0
# 208751 -0.316818  0.128774 -0.144953  0.060158  0.125289   11.45      0
# 219060 -0.550918 -0.717056 -1.011986  0.095221 -0.000809  167.38      0
# 172061 -0.012077 -0.605113 -0.406069  0.007689 -0.034534    0.79      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 68502   0.073856  0.172142  0.752676 -1.250197  0.007994   30.00      0
# 52944   0.054937  0.022782  0.958963 -0.012099  0.013147   30.87      0
# 133330 -0.729296  0.197195 -0.421200  0.130802  0.045716   13.85      0
# 179023  0.706993  0.441779 -0.536539 -0.039814 -0.063876   20.00      0
# 94737  -1.386770  0.748387 -0.238960  0.021528 -0.012022    9.46      0
#
# [492 rows x 31 columns]

# %%
new_dataset = pd.concat([non_fraud_sample,fraud],axis = 0)

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94290.140244 -0.048377 -0.063653  0.080144 -0.030065 -0.058654
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.039211  0.031593 -0.001800  0.031676  ... -0.041673 -0.050277
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.016003 -0.010364 -0.022036 -0.055582  0.007361  0.007195  0.002334
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       93.102805
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
##Splitting the data into Features and targets

# %%
X = new_dataset.drop(columns='Class',axis=1)
y = new_dataset['Class']

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279684  169029.0  2.048629 -0.367489 -2.544065 -0.728472  2.387380  3.318407
# 193518  130169.0  2.080152 -0.992287 -0.801193 -0.316387 -1.095972 -0.861556
# 208751  137256.0 -0.616217 -0.390294  0.657761 -2.354112  0.667513 -1.105439
# 219060  141578.0  1.637149 -1.215307 -0.788944  0.574019 -0.089768  1.620323
# 172061  120937.0  1.828424  0.357172  0.350213  3.725494 -0.231331  0.365355
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 279684 -0.477692  0.791276  0.403246  ... -0.152758 -0.292703 -0.835377
# 193518 -0.688245 -0.149169  0.058034  ... -0.620440 -0.369796 -0.583782
# 208751  0.145951 -0.049400 -1.437412  ...  0.108340  0.492708  1.093832
# 219060 -0.719414  0.408515 -0.191236  ... -0.404611 -0.575824 -1.284330
# 172061 -0.470625  0.214984 -0.735357  ... -0.275536 -0.143005 -0.422536
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  1.252967  0.778584 -0.319189
# 280143 -1.413170  0.248525 -1.127396  ...  0.226138  0.370612  0.028234
# 280149 -2.234739  1.210158 -0.652250  ...  0.247968  0.751826  0.834108
# 281144 -2.208002  1.058733 -1.632333  ...  0.306271  0.583276 -0.269209
# 281674  0.223050 -0.068384  0.577829  ... -0.017652 -0.164350 -0.295135
#
#              V23       V24       V25       V26       V27       V28  Amount
# 279684  0.380780  0.698235 -0.265199  0.219159 -0.052337 -0.066750    1.98
# 193518  0.267047 -0.149192 -0.417916  0.566911 -0.047929 -0.049811   45.00
# 208751 -0.292204 -0.316818  0.128774 -0.144953  0.060158  0.125289   11.45
# 219060  0.471007 -0.550918 -0.717056 -1.011986  0.095221 -0.000809  167.38
# 172061  0.440547 -0.012077 -0.605113 -0.406069  0.007689 -0.034534    0.79
# ...          ...       ...       ...       ...       ...       ...     ...
# 279863  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00
# 280143 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76
# 280149  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89
# 281144 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00
# 281674 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53
#
# [984 rows x 30 columns]

# %%
y
# Out:
# 279684    0
# 193518    0
# 208751    0
# 219060    0
# 172061    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
## Split the Data into Training and testing

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y, random_state=2)

# %%
X.shape , X_train.shape , X_test.shape
# Out:
# ((984, 30), (787, 30), (197, 30))

# %%
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
## Accuracy on training Data
Train_pred = logistic_model.predict(X_train)
accuracy1 = accuracy_score(y_train, Train_pred)
print("Accuracy:", accuracy1)
# Out:
# Accuracy: 0.9428208386277002

# %%
## Accuracy on test data
Test_pred = logistic_model.predict(X_test)
accuracy1 = accuracy_score(y_test, Test_pred)
print("Accuracy:", accuracy1)
# Out:
# Accuracy: 0.9289340101522843
